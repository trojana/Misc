# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:16, 1.88MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
with open('data/text8') as f:
    text = f.read()
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6490 0.2845 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5997 0.2776 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5321 0.2707 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5983 0.3080 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5011 0.2814 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5504 0.2766 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5803 0.2734 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5521 0.2700 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4740 0.2719 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4250 0.2764 sec/batch
# Nearest to i: vietnamese, chopsticks, lifeson, ditch, deathscythe, mihai, excused, sncb,
# Nearest to than: eastwards, hats, carisbrooke, dunkeld, worried, flo, personalities, pah,
# Nearest to between: earthbound, chaos, fern, deeps, jebel, landings, acme, pneumatic,
# Nearest to american: barrett, swollen, italica, listed, milenko, thalberg, superstar, manzoni,
# Nearest to the: deputies, imports, snowshoe, heschel, chemist, unpublished, mandatory, tya,
# Nearest to b: manasses, invitational, henceforward, saban, nasa, mahmud, knobs, washburn,
# Nearest to or: palaestina, lunisolar, translating, elegans, piccard, shack, hymenoptera, demotic,
# Nearest to who: implanted, paleogeography, bornemisza, confusingly, long, burial, entangling, lland,
# Nearest to gold: milk, flak, boyband, partially, hoagie, unstated, sign, harnessing,
# Nearest to operations: unwittingly, anselm, decline, oldest, bracelet, diario, sensitive, swinging,
# Nearest to except: petrie, treaty, naturalized, conjunctivitis, progeny, cheapest, hatchback, springsteen,
# Nearest to existence: demoralized, cerro, authorizes, pontiff, singularity, steels, waff, propriety,
# Nearest to rise: kv, allan, buy, sunyaev, interchange, hirschfeld, awoke, saavedra,
# Nearest to placed: valuations, wilt, martius, steadfast, omnibus, hatfield, gothicus, mariani,
# Nearest to san: boys, equations, monsoonal, chased, digamma, fetching, rigor, koreans,
# Nearest to hold: delaney, tonalsoft, diners, caters, afghans, needless, forefathers, replay,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4959 0.2769 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3920 0.2793 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3532 0.2801 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2340 0.2753 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2315 0.2740 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1699 0.2990 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1128 0.3112 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0854 0.3018 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0387 0.3008 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9799 0.3029 sec/batch
# Nearest to i: vietnamese, chopsticks, lifeson, ditch, ability, excused, mihai, basically,
# Nearest to than: worried, eastwards, relations, hats, personalities, carisbrooke, historically, studies,
# Nearest to between: earthbound, started, collectivized, chaos, landings, constraints, proportional, purgatory,
# Nearest to american: barrett, listed, italica, swollen, superstar, federal, alumnus, churchland,
# Nearest to the: deputies, imports, technology, snowshoe, unpublished, mandatory, been, orange,
# Nearest to b: selection, nasa, cut, l, manasses, purchased, phd, mahmud,
# Nearest to or: palaestina, turned, translating, due, castle, improvement, means, sites,
# Nearest to who: long, confusingly, revival, burial, implanted, las, introduction, doubtless,
# Nearest to gold: partially, milk, flak, boyband, tiger, sign, purposes, unstated,
# Nearest to operations: decline, oldest, unwittingly, sensitive, position, swinging, likely, belong,
# Nearest to except: treaty, petrie, censored, message, e, conjunctivitis, freescale, oft,
# Nearest to existence: demoralized, pontiff, authorizes, cerro, dungeons, bergman, regulate, puck,
# Nearest to rise: buy, interchange, beginning, kv, awoke, allan, greater, sunyaev,
# Nearest to placed: wilt, martius, valuations, omnibus, gothicus, steadfast, superstar, infielder,
# Nearest to san: boys, equations, chased, koreans, monsoonal, fetching, rigor, poto,
# Nearest to hold: delaney, tonalsoft, needless, entangled, replay, painting, afghans, seems,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9427 0.3045 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9274 0.3015 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8841 0.3043 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8974 0.3072 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8224 0.2994 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8438 0.3018 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7881 0.3002 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7817 0.3014 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7944 0.3032 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7619 0.3023 sec/batch
# Nearest to i: vietnamese, lifeson, chopsticks, basically, mihai, excused, coincidentally, functionalism,
# Nearest to than: hats, relations, carisbrooke, eastwards, worried, personalities, dunkeld, bomb,
# Nearest to between: earthbound, proportional, chaos, landings, liberalization, pneumatic, credence, collectivized,
# Nearest to american: barrett, swollen, three, baghdad, listed, italica, alumnus, manzoni,
# Nearest to the: deputies, imports, deprivation, scoring, snowshoe, heschel, phenomenon, shell,
# Nearest to b: nasa, selection, chemistry, phd, purchased, manasses, henceforward, l,
# Nearest to or: palaestina, turned, translating, improvement, lunisolar, geometric, shack, due,
# Nearest to who: confusingly, revival, long, burial, implanted, las, quotient, geometrically,
# Nearest to gold: partially, milk, flak, tiger, passionate, boyband, unstated, raked,
# Nearest to operations: decline, sensitive, unwittingly, oldest, anselm, sessions, extremities, tried,
# Nearest to except: treaty, petrie, progeny, censored, naturalized, oft, textbooks, conjunctivitis,
# Nearest to existence: demoralized, authorizes, pontiff, regulate, propriety, cerro, singularity, goblins,
# Nearest to rise: buy, kv, interchange, allan, beginning, awoke, swedish, sunyaev,
# Nearest to placed: wilt, valuations, martius, omnibus, steadfast, exacerbating, devising, gothicus,
# Nearest to san: boys, koreans, chased, equations, monsoonal, fetching, poto, rigor,
# Nearest to hold: delaney, tonalsoft, replay, needless, entangled, totalitarianism, afghans, seems,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7679 0.3039 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7589 0.3000 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7221 0.3021 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6962 0.2992 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7402 0.2879 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7118 0.3218 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6876 0.2930 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6999 0.2913 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6781 0.2959 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6573 0.2984 sec/batch
# Nearest to i: vietnamese, lifeson, chopsticks, mihai, horseback, excused, pickering, coincidentally,
# Nearest to than: hats, carisbrooke, eastwards, dunkeld, relations, worried, survive, bigotry,
# Nearest to between: earthbound, proportional, chaos, credence, landings, pneumatic, liberalization, jebel,
# Nearest to american: three, baghdad, swollen, stevens, wow, barrett, kennedy, attracting,
# Nearest to the: deputies, deprivation, eighteen, heschel, caricom, phenomenon, slick, populous,
# Nearest to b: nobel, stanton, passions, henceforward, mahmud, intersexual, alaska, dramas,
# Nearest to or: palaestina, hofstadter, turned, outlines, lunisolar, translating, eggs, shack,
# Nearest to who: confusingly, revival, drury, implanted, burial, exceed, long, geometrically,
# Nearest to gold: partially, flak, milk, harnessing, boyband, unstated, tiger, passionate,
# Nearest to operations: decline, sensitive, unwittingly, anselm, extremities, oldest, swinging, sessions,
# Nearest to except: petrie, naturalized, progeny, oft, censored, treaty, conjunctivitis, e,
# Nearest to existence: demoralized, authorizes, pontiff, regulate, propriety, cerro, goblins, bergman,
# Nearest to rise: kv, buy, awoke, interchange, sunyaev, allan, greater, stuck,
# Nearest to placed: wilt, martius, valuations, omnibus, hatfield, steadfast, exacerbating, devonshire,
# Nearest to san: chased, boys, monsoonal, fetching, koreans, poto, treacherous, rigor,
# Nearest to hold: tonalsoft, replay, totalitarianism, delaney, afghans, forefathers, diners, seems,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6702 0.2974 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6504 0.2958 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6256 0.2995 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6403 0.2927 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6435 0.2939 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6420 0.2956 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5996 0.2091 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5726 0.2926 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4981 0.2914 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5152 0.2901 sec/batch
# Nearest to i: lifeson, vietnamese, mihai, pickering, chopsticks, horseback, functionalism, excused,
# Nearest to than: carisbrooke, hats, eastwards, relations, dunkeld, survive, irreducible, gout,
# Nearest to between: earthbound, proportional, nul, jebel, pneumatic, credence, deeps, chaos,
# Nearest to american: three, baghdad, stevens, actor, andre, kennedy, born, wow,
# Nearest to the: deputies, deprivation, heschel, intercession, phenomenon, caricom, eighteen, been,
# Nearest to b: nobel, author, stanton, mahmud, psychologist, intersexual, l, anita,
# Nearest to or: hofstadter, due, palaestina, lunisolar, eggs, carbons, default, piccard,
# Nearest to who: revival, drury, fronts, distraction, entangling, confusingly, implanted, burial,
# Nearest to gold: partially, flak, unstated, harnessing, boyband, milk, raked, tiger,
# Nearest to operations: decline, sensitive, anselm, extremities, unwittingly, swinging, daunting, lieder,
# Nearest to except: petrie, progeny, naturalized, conjunctivitis, censored, oft, e, textbooks,
# Nearest to existence: demoralized, authorizes, pontiff, propriety, regulate, cerro, goblins, sedans,
# Nearest to rise: kv, awoke, buy, sunyaev, greater, stuck, spoil, beginning,
# Nearest to placed: martius, valuations, wilt, exacerbating, scalars, devonshire, devising, hatfield,
# Nearest to san: chased, boys, fetching, monsoonal, koreans, poto, treacherous, axelrod,
# Nearest to hold: tonalsoft, replay, afghans, totalitarianism, forefathers, delaney, entangled, diners,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4956 0.2922 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4818 0.2898 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4753 0.2908 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5335 0.2945 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4854 0.2950 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5062 0.2947 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4539 0.2968 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4070 0.2999 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4266 0.3001 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4007 0.2958 sec/batch
# Nearest to i: lifeson, mihai, vietnamese, pickering, chopsticks, excused, functionalism, snares,
# Nearest to than: hats, carisbrooke, eastwards, relations, dunkeld, survive, appetite, gout,
# Nearest to between: deeps, earthbound, proportional, jebel, nul, chaos, pneumatic, credence,
# Nearest to american: baghdad, stevens, medals, andre, barrett, kennedy, cosimo, three,
# Nearest to the: heschel, phenomenon, been, deputies, intercession, divided, caricom, populous,
# Nearest to b: nobel, stanton, l, mahmud, intersexual, hippocrates, j, henceforward,
# Nearest to or: lunisolar, palaestina, stakeholders, due, eggs, hydrogen, hofstadter, carbons,
# Nearest to who: revival, distraction, entangling, fronts, burial, vanity, lived, drury,
# Nearest to gold: partially, flak, harnessing, duklja, raked, unstated, boyband, sardines,
# Nearest to operations: sensitive, anselm, decline, extremities, daunting, tekniska, lieder, swinging,
# Nearest to except: naturalized, petrie, conjunctivitis, progeny, censored, textbooks, oft, accomplishment,
# Nearest to existence: pontiff, demoralized, propriety, authorizes, cerro, goblins, regulate, contemplation,
# Nearest to rise: kv, awoke, buy, greater, stuck, hirschfeld, spoil, sunyaev,
# Nearest to placed: valuations, scalars, exacerbating, devonshire, martius, wilt, propel, devising,
# Nearest to san: chased, monsoonal, boys, fetching, boulevard, poto, axelrod, duchies,
# Nearest to hold: tonalsoft, forefathers, replay, delaney, afghans, totalitarianism, entangled, seems,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4338 0.3003 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4187 0.2952 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4436 0.2687 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3916 0.2668 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4166 0.2680 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4182 0.2798 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3752 0.2935 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3894 0.2660 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4211 0.2613 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3746 0.2606 sec/batch
# Nearest to i: lifeson, mihai, pickering, horseback, excused, vietnamese, chopsticks, snares,
# Nearest to than: hats, carisbrooke, eastwards, relations, gout, basis, inheriting, worried,
# Nearest to between: deeps, earthbound, proportional, credence, jebel, pneumatic, chaos, infra,
# Nearest to american: stevens, medals, andre, kennedy, baghdad, three, alumnus, actor,
# Nearest to the: heschel, intercession, tuition, divided, deputies, been, shell, sappho,
# Nearest to b: nobel, l, stanton, mahmud, j, intersexual, author, hippocrates,
# Nearest to or: palaestina, due, stakeholders, carbons, crankshaft, debugged, lunisolar, eggs,
# Nearest to who: revival, distraction, burial, fronts, vanity, drury, lived, entangling,
# Nearest to gold: partially, flak, duklja, harnessing, sardines, tiger, raked, unstated,
# Nearest to operations: sensitive, decline, anselm, daunting, tekniska, extremities, lieder, aircraft,
# Nearest to except: petrie, conjunctivitis, progeny, textbooks, naturalized, oft, censored, treaty,
# Nearest to existence: pontiff, propriety, authorizes, demoralized, regulate, cerro, contemplation, goblins,
# Nearest to rise: kv, awoke, buy, greater, stuck, spoil, hirschfeld, glosses,
# Nearest to placed: valuations, scalars, devonshire, exacerbating, devising, propel, martius, wilt,
# Nearest to san: chased, boys, monsoonal, fetching, axelrod, poto, boulevard, duchies,
# Nearest to hold: forefathers, tonalsoft, replay, afghans, entangled, totalitarianism, bureaucrats, needless,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3725 0.2625 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3946 0.2605 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3711 0.2600 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3812 0.2607 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4261 0.2628 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3582 0.2731 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3732 0.2776 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3980 0.2858 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3053 0.2736 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3281 0.2638 sec/batch
# Nearest to i: lifeson, pickering, mihai, excused, chopsticks, vietnamese, horseback, deathscythe,
# Nearest to than: hats, carisbrooke, eastwards, inheriting, allosteric, gout, basis, worried,
# Nearest to between: deeps, jebel, credence, proportional, earthbound, infra, chaos, pneumatic,
# Nearest to american: medals, stevens, kennedy, andre, barrett, alumnus, baghdad, actors,
# Nearest to the: heschel, local, deputies, divided, of, region, successfully, populous,
# Nearest to b: nobel, l, j, mahmud, stanton, hippocrates, x, washburn,
# Nearest to or: debugged, carbons, stakeholders, palaestina, due, eggs, crankshaft, means,
# Nearest to who: revival, burial, distraction, lived, entangling, fronts, aaronic, knowing,
# Nearest to gold: partially, duklja, flak, harnessing, sardines, raked, tiger, appetites,
# Nearest to operations: sensitive, tekniska, anselm, decline, aircraft, extremities, daunting, wagons,
# Nearest to except: conjunctivitis, progeny, oft, petrie, textbooks, censored, treaty, hatchback,
# Nearest to existence: pontiff, authorizes, propriety, demoralized, contemplation, cerro, forlorn, moral,
# Nearest to rise: kv, awoke, greater, stuck, buy, spiegel, hirschfeld, spoil,
# Nearest to placed: scalars, valuations, exacerbating, propel, martius, devonshire, wilt, devising,
# Nearest to san: chased, boys, fetching, boulevard, monsoonal, axelrod, poto, kobe,
# Nearest to hold: forefathers, tonalsoft, replay, entangled, totalitarianism, afghans, delaney, crossrail,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3249 0.2675 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2944 0.2667 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3784 0.2679 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3835 0.2715 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3966 0.2833 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2952 0.2874 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3028 0.2799 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3561 0.2818 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2226 0.2729 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2929 0.2854 sec/batch
# Nearest to i: lifeson, mihai, pickering, excused, horseback, snares, zwinger, reaped,
# Nearest to than: eastwards, hats, carisbrooke, inheriting, weighting, allosteric, basis, relations,
# Nearest to between: deeps, jebel, proportional, credence, corleone, earthbound, nul, chaos,
# Nearest to american: kennedy, stevens, andre, medals, actor, barrett, songwriter, comedian,
# Nearest to the: heschel, divided, deputies, local, successfully, tuition, bandar, of,
# Nearest to b: nobel, j, author, mahmud, l, psychologist, stanton, physicist,
# Nearest to or: carbons, stakeholders, debugged, means, eggs, compulsories, lunisolar, palaestina,
# Nearest to who: distraction, revival, entangling, burial, implanted, aaronic, vanity, lived,
# Nearest to gold: partially, duklja, tiger, flak, harnessing, sardines, raked, appetites,
# Nearest to operations: tekniska, sensitive, anselm, aircraft, decline, freebsd, engravers, wagons,
# Nearest to except: conjunctivitis, progeny, petrie, oft, textbooks, hatchback, censored, treaty,
# Nearest to existence: pontiff, contemplation, propriety, demoralized, authorizes, forlorn, cerro, goblins,
# Nearest to rise: kv, awoke, stuck, greater, buy, spiegel, martyrs, beginning,
# Nearest to placed: scalars, propel, martius, valuations, exacerbating, devonshire, comparisons, devising,
# Nearest to san: chased, axelrod, kobe, boys, monsoonal, fetching, cuyo, poto,
# Nearest to hold: tonalsoft, forefathers, replay, entangled, afghans, totalitarianism, bureaucrats, delaney,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3074 0.2962 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3132 0.2846 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3149 0.1308 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2489 0.2854 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2329 0.2805 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2115 0.2922 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2161 0.2779 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2000 0.2773 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2419 0.2791 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1814 0.2764 sec/batch
# Nearest to i: mihai, pickering, lifeson, assyrian, zwinger, reaped, chopsticks, excused,
# Nearest to than: eastwards, hats, carisbrooke, inheriting, gout, weighting, exceeding, allosteric,
# Nearest to between: deeps, jebel, proportional, earthbound, infra, nul, pneumatic, pazzi,
# Nearest to american: kennedy, medals, stevens, barrett, andre, aspirate, tach, songwriter,
# Nearest to the: of, eighteen, divided, deputies, heschel, at, caricom, populous,
# Nearest to b: nobel, l, j, hippocrates, mahmud, psychologist, cdot, physicist,
# Nearest to or: carbons, stakeholders, eggs, due, debugged, improper, compulsories, palaestina,
# Nearest to who: entangling, revival, distraction, burial, implanted, bornemisza, lived, aaronic,
# Nearest to gold: partially, duklja, sardines, flak, tiger, harnessing, raked, unstated,
# Nearest to operations: tekniska, sensitive, aircraft, anselm, freebsd, vectors, wagons, countably,
# Nearest to except: conjunctivitis, progeny, oft, petrie, hatchback, treaty, naturalized, censored,
# Nearest to existence: pontiff, contemplation, demoralized, propriety, authorizes, judgement, forlorn, goblins,
# Nearest to rise: kv, awoke, greater, stuck, martyrs, intensified, landlocked, spiegel,
# Nearest to placed: scalars, propel, exacerbating, martius, valuations, comparisons, devising, manoeuvres,
# Nearest to san: kobe, cuyo, chased, axelrod, monsoonal, boys, fetching, buckle,
# Nearest to hold: tonalsoft, forefathers, replay, afghans, entangled, totalitarianism, bureaucrats, delaney,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2574 0.2805 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2266 0.2779 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2403 0.2774 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1384 0.2782 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2193 0.2782 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1690 0.2782 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1499 0.2839 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1864 0.2713 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2078 0.2645 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1765 0.2638 sec/batch
# Nearest to i: pickering, mihai, excused, zwinger, lifeson, reaped, chopsticks, assyrian,
# Nearest to than: eastwards, hats, carisbrooke, inheriting, exceeding, gout, basis, weighting,
# Nearest to between: jebel, deeps, earthbound, pneumatic, proportional, nul, dedekind, credence,
# Nearest to american: medals, barrett, kennedy, stevens, tach, aspirate, animist, andre,
# Nearest to the: of, divided, aspirated, heschel, eighteen, equivalence, a, meiotic,
# Nearest to b: l, cdot, x, hippocrates, nobel, j, ei, mahmud,
# Nearest to or: carbons, stakeholders, due, stimulation, adverts, means, debugged, arrows,
# Nearest to who: revival, implanted, aaronic, distraction, bornemisza, burial, entangling, vanity,
# Nearest to gold: partially, sardines, duklja, flak, tiger, harnessing, manganese, milk,
# Nearest to operations: tekniska, sensitive, aircraft, anselm, freebsd, transporting, wagons, revalued,
# Nearest to except: progeny, conjunctivitis, petrie, oft, censored, hatchback, naturalized, treaty,
# Nearest to existence: contemplation, pontiff, judgement, propriety, heterochromatin, authorizes, waff, forlorn,
# Nearest to rise: kv, awoke, stuck, greater, hirschfeld, martyrs, prey, decreasing,
# Nearest to placed: propel, exacerbating, comparisons, scalars, mariani, devonshire, martius, dragster,
# Nearest to san: kobe, chased, cuyo, francisco, boulevard, boys, fetching, monsoonal,
# Nearest to hold: tonalsoft, replay, forefathers, entangled, bureaucrats, afghans, totalitarianism, delaney,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1684 0.2655 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2501 0.2642 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1598 0.2650 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1614 0.2640 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1834 0.2634 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1988 0.2636 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1969 0.2643 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1813 0.2635 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1361 0.2705 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1717 0.2623 sec/batch
# Nearest to i: mihai, pickering, excused, reaped, zwinger, lifeson, assyrian, chopsticks,
# Nearest to than: eastwards, hats, inheriting, carisbrooke, gout, basis, weighting, allosteric,
# Nearest to between: jebel, proportional, deeps, pneumatic, chaos, earthbound, infra, credence,
# Nearest to american: medals, barrett, stevens, kennedy, andre, tach, aspirate, actor,
# Nearest to the: of, tuition, divided, aspirated, successfully, semper, been, deputies,
# Nearest to b: nobel, l, mahmud, hippocrates, x, cdot, j, washburn,
# Nearest to or: carbons, stakeholders, means, debugged, crankshaft, conductors, arrows, due,
# Nearest to who: revival, aaronic, burial, implanted, bornemisza, vanity, entangling, fronts,
# Nearest to gold: partially, sardines, manganese, tiger, duklja, potash, harnessing, flak,
# Nearest to operations: tekniska, sensitive, aircraft, anselm, wagons, revalued, freebsd, transporting,
# Nearest to except: conjunctivitis, progeny, oft, petrie, textbooks, treaty, represented, censored,
# Nearest to existence: contemplation, pontiff, authorizes, judgement, propriety, singularity, cerro, heterochromatin,
# Nearest to rise: kv, awoke, stuck, greater, martyrs, hirschfeld, duels, buy,
# Nearest to placed: propel, scalars, exacerbating, dragster, mariani, refractory, devising, comparisons,
# Nearest to san: kobe, chased, cuyo, francisco, boys, axelrod, fetching, buckle,
# Nearest to hold: tonalsoft, replay, forefathers, entangled, bureaucrats, afghans, crossrail, needless,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2289 0.2665 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1549 0.2675 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1761 0.2658 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2000 0.2640 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1505 0.2654 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1476 0.2626 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1880 0.2635 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1294 0.2658 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1939 0.2663 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2135 0.2651 sec/batch
# Nearest to i: pickering, mihai, zwinger, excused, reaped, assyrian, lifeson, budge,
# Nearest to than: eastwards, inheriting, hats, jardine, gout, weighting, carisbrooke, roof,
# Nearest to between: deeps, jebel, credence, proportional, pneumatic, corleone, infra, chaos,
# Nearest to american: barrett, stevens, andre, medals, kennedy, tach, actor, martins,
# Nearest to the: of, a, by, deputies, tuition, heschel, snider, at,
# Nearest to b: nobel, mahmud, ballerina, egon, broglie, author, j, l,
# Nearest to or: stakeholders, carbons, means, compulsories, debugged, maududi, lunisolar, palaestina,
# Nearest to who: revival, entangling, aaronic, bornemisza, implanted, burial, disloyalty, renewed,
# Nearest to gold: sardines, duklja, partially, tiger, manganese, potash, flak, harnessing,
# Nearest to operations: tekniska, sensitive, anselm, aircraft, revalued, wagons, cybernetica, freebsd,
# Nearest to except: conjunctivitis, progeny, oft, petrie, naturalized, censored, jews, represented,
# Nearest to existence: contemplation, pontiff, authorizes, cerro, propriety, bergman, judgement, demoralized,
# Nearest to rise: kv, awoke, martyrs, persecution, greater, stuck, tenochtitl, duels,
# Nearest to placed: exacerbating, scalars, mariani, devising, dragster, propel, comparisons, valuations,
# Nearest to san: cuyo, kobe, chased, francisco, axelrod, fur, nakata, treacherous,
# Nearest to hold: tonalsoft, replay, bureaucrats, afghans, crossrail, forefathers, entangled, imperial,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2603 0.2661 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1320 0.2651 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0879 0.2617 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1526 0.2624 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0224 0.2640 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1457 0.2636 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1346 0.2643 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1128 0.2644 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1776 0.0507 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1064 0.2641 sec/batch
# Nearest to i: pickering, mihai, zwinger, excused, reaped, assyrian, lifeson, ditch,
# Nearest to than: eastwards, inheriting, gout, hats, less, mechanism, carisbrooke, basis,
# Nearest to between: deeps, jebel, proportional, credence, zodiac, pneumatic, earthbound, nul,
# Nearest to american: barrett, stevens, medals, kennedy, tach, andre, actor, animist,
# Nearest to the: of, a, by, also, at, local, heschel, from,
# Nearest to b: nobel, mahmud, broglie, hippocrates, washburn, correspondence, egon, psychologist,
# Nearest to or: carbons, transmitter, eggs, means, compulsories, stakeholders, conductors, sites,
# Nearest to who: implanted, bornemisza, revival, entangling, aaronic, vanity, burial, renewed,
# Nearest to gold: sardines, duklja, partially, manganese, tiger, rowing, flak, harnessing,
# Nearest to operations: tekniska, anselm, sensitive, aircraft, freebsd, wagons, combination, vectors,
# Nearest to except: conjunctivitis, progeny, petrie, oft, hatchback, modicum, censored, script,
# Nearest to existence: contemplation, pontiff, authorizes, bergman, propriety, heterochromatin, cerro, judgement,
# Nearest to rise: kv, awoke, greater, stuck, persecution, martyrs, decreasing, decades,
# Nearest to placed: scalars, comparisons, dragster, propel, mariani, refractory, exacerbating, unsanitary,
# Nearest to san: cuyo, kobe, francisco, chased, boys, nakata, ieoh, axelrod,
# Nearest to hold: replay, tonalsoft, afghans, bureaucrats, crossrail, entangled, forefathers, selberg,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0725 0.2668 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0844 0.2675 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0790 0.2649 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0588 0.2651 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0866 0.2672 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0505 0.2647 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1042 0.2642 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0979 0.2637 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1012 0.2643 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0074 0.2634 sec/batch
# Nearest to i: pickering, excused, mihai, reaped, assyrian, zwinger, chopsticks, ditch,
# Nearest to than: eastwards, prices, gout, less, inheriting, exceeding, mechanism, hats,
# Nearest to between: deeps, jebel, pneumatic, proportional, zodiac, excavators, chaos, credence,
# Nearest to american: barrett, stevens, medals, animist, tach, kennedy, marsalis, trey,
# Nearest to the: of, a, been, by, from, divided, also, populous,
# Nearest to b: hippocrates, mahmud, broglie, washburn, nobel, futures, exponentiation, neumann,
# Nearest to or: carbons, stakeholders, conductors, transmitter, means, accompanying, sites, stimulation,
# Nearest to who: aaronic, implanted, bornemisza, revival, entangling, vanity, compleat, their,
# Nearest to gold: sardines, duklja, manganese, partially, tiger, ore, rowing, glue,
# Nearest to operations: sensitive, tekniska, wagons, anselm, vectors, combination, panzer, aircraft,
# Nearest to except: conjunctivitis, progeny, oft, petrie, naturalized, hatchback, modicum, script,
# Nearest to existence: contemplation, pontiff, propriety, bergman, authorizes, cerro, judgement, inclusively,
# Nearest to rise: kv, awoke, greater, stuck, martyrs, hirschfeld, spiegel, persecution,
# Nearest to placed: propel, krapina, flamethrower, comparisons, dalglish, refractory, scalars, tibia,
# Nearest to san: francisco, cuyo, kobe, chased, boys, ribeira, juan, treacherous,
# Nearest to hold: replay, tonalsoft, bureaucrats, afghans, entangled, crossrail, forefathers, selberg,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0073 0.2673 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0460 0.2666 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0144 0.2785 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0573 0.2641 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0642 0.2648 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0431 0.2637 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0681 0.2638 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0930 0.2650 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0438 0.2649 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0367 0.2645 sec/batch
# Nearest to i: pickering, excused, zwinger, assyrian, mihai, think, reaped, ditch,
# Nearest to than: eastwards, inheriting, gout, basis, prices, less, exceeding, cretinism,
# Nearest to between: deeps, jebel, pneumatic, credence, proportional, chaos, zodiac, excavators,
# Nearest to american: barrett, medals, stevens, tach, animist, kennedy, trey, marsalis,
# Nearest to the: of, a, by, from, each, ubuntu, been, is,
# Nearest to b: mahmud, broglie, washburn, egon, hippocrates, exponentiation, nobel, correspondence,
# Nearest to or: carbons, stakeholders, present, means, oxidise, carotene, accompanying, sites,
# Nearest to who: aaronic, implanted, bornemisza, vanity, compleat, revival, entangling, lived,
# Nearest to gold: sardines, duklja, manganese, partially, rowing, tiger, ore, potash,
# Nearest to operations: sensitive, tekniska, vectors, combination, wagons, anselm, panzer, aircraft,
# Nearest to except: oft, conjunctivitis, progeny, petrie, naturalized, contest, inlay, modicum,
# Nearest to existence: contemplation, pontiff, singularity, waff, cerro, bergman, propriety, heterochromatin,
# Nearest to rise: kv, awoke, stuck, greater, duels, martyrs, hirschfeld, lasers,
# Nearest to placed: refractory, propel, silicone, flamethrower, scalars, unsanitary, tibia, devising,
# Nearest to san: francisco, cuyo, kobe, chased, juan, ribeira, treacherous, boys,
# Nearest to hold: bureaucrats, replay, tonalsoft, afghans, entangled, crossrail, delaney, selberg,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0560 0.2655 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0609 0.2649 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0747 0.2646 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0700 0.2632 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0511 0.2649 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0741 0.2650 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0897 0.2637 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0383 0.2652 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0763 0.2653 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0673 0.2640 sec/batch
# Nearest to i: pickering, excused, assyrian, reaped, mihai, think, ditch, zwinger,
# Nearest to than: eastwards, inheriting, prices, less, gout, cretinism, equal, basis,
# Nearest to between: jebel, deeps, pneumatic, credence, proportional, neogene, excavators, chaos,
# Nearest to american: barrett, animist, tach, stevens, kennedy, medals, trey, asian,
# Nearest to the: of, by, in, from, been, a, was, ugaritic,
# Nearest to b: mahmud, washburn, broglie, hippocrates, egon, neumann, magnus, decimals,
# Nearest to or: maududi, cry, stakeholders, heb, accompanying, means, demigods, fricatives,
# Nearest to who: aaronic, revival, implanted, bornemisza, mitford, vanity, burial, their,
# Nearest to gold: sardines, manganese, duklja, potash, ore, partially, glue, rowing,
# Nearest to operations: sensitive, tekniska, anselm, wagons, panzer, aircraft, combination, vectors,
# Nearest to except: conjunctivitis, oft, progeny, petrie, fielding, contest, naturalized, jews,
# Nearest to existence: contemplation, pontiff, cerro, bergman, authorizes, waff, singularity, propriety,
# Nearest to rise: kv, awoke, greater, stuck, duels, hirschfeld, martyrs, persecution,
# Nearest to placed: flamethrower, refractory, mariani, tibia, krapina, manoeuvres, propel, silicone,
# Nearest to san: francisco, cuyo, kobe, chased, juan, ribeira, nakata, treacherous,
# Nearest to hold: tonalsoft, bureaucrats, afghans, replay, crossrail, entangled, imperial, selberg,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0495 0.2668 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0156 0.2638 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0231 0.2634 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0875 0.2661 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0788 0.2677 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1015 0.2661 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1323 0.2634 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0388 0.2645 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0656 0.2638 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0820 0.2632 sec/batch
# Nearest to i: pickering, think, excused, zwinger, know, mihai, you, assyrian,
# Nearest to than: eastwards, prices, less, equal, inheriting, gout, exceeding, cretinism,
# Nearest to between: deeps, jebel, neogene, pneumatic, excavators, credence, proportional, revert,
# Nearest to american: barrett, kennedy, tach, animist, stevens, medals, actor, haas,
# Nearest to the: of, by, a, from, been, in, also, was,
# Nearest to b: mahmud, broglie, washburn, hippocrates, neumann, milner, decimals, magnus,
# Nearest to or: means, carbons, stakeholders, maududi, kihei, cases, cypriot, nada,
# Nearest to who: implanted, aaronic, lived, their, mitford, revival, entangling, disloyalty,
# Nearest to gold: sardines, duklja, manganese, potash, partially, passionate, glue, rowing,
# Nearest to operations: sensitive, tekniska, wagons, vectors, anselm, combination, panzer, freebsd,
# Nearest to except: conjunctivitis, oft, progeny, modicum, petrie, bridgestone, inlay, contest,
# Nearest to existence: contemplation, pontiff, authorizes, bergman, cerro, waff, propriety, coldly,
# Nearest to rise: kv, awoke, greater, duels, stuck, stagnated, decreasing, persecution,
# Nearest to placed: flamethrower, silicone, mariani, tibia, manoeuvres, refractory, comparisons, scalars,
# Nearest to san: francisco, cuyo, kobe, chased, juan, ribeira, nakata, california,
# Nearest to hold: bureaucrats, tonalsoft, replay, crossrail, entangled, afghans, gamble, delaney,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9938 0.2668 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0328 0.2654 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0423 0.2650 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0290 0.2642 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0524 0.2653 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0593 0.2455 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0006 0.2720 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9938 0.2666 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0023 0.2654 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9825 0.2661 sec/batch
# Nearest to i: pickering, assyrian, reaped, zwinger, excused, know, mihai, think,
# Nearest to than: eastwards, less, prices, gout, equal, simpler, inheriting, exceeding,
# Nearest to between: deeps, neogene, pneumatic, jebel, earthbound, chakras, credence, excavators,
# Nearest to american: barrett, actor, animist, tach, kennedy, haas, trey, stevens,
# Nearest to the: of, by, a, from, in, been, meiotic, anabaptist,
# Nearest to b: mahmud, washburn, broglie, magnus, neumann, dudley, nobel, psychologist,
# Nearest to or: cypriot, carbons, kihei, penalties, maududi, accompanying, stakeholders, heb,
# Nearest to who: implanted, aaronic, entangling, bornemisza, lived, mitford, disloyalty, their,
# Nearest to gold: sardines, duklja, manganese, glue, passionate, ore, partially, eucharistic,
# Nearest to operations: wagons, sensitive, tekniska, panzer, aircraft, macao, combination, vectors,
# Nearest to except: conjunctivitis, oft, progeny, modicum, inlay, petrie, contest, troughs,
# Nearest to existence: contemplation, pontiff, propriety, waff, bergman, singularity, judgement, inclusively,
# Nearest to rise: kv, greater, awoke, decreasing, stuck, precipitation, duels, graded,
# Nearest to placed: flamethrower, mariani, haw, silicone, tibia, anakin, manoeuvres, mace,
# Nearest to san: francisco, cuyo, kobe, juan, chased, ribeira, treacherous, ieoh,
# Nearest to hold: bureaucrats, tonalsoft, replay, afghans, crossrail, entangled, delaney, artistry,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9535 0.2687 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9428 0.2642 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0298 0.2638 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9960 0.2641 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0140 0.2645 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9948 0.2646 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9160 0.2655 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9369 0.2671 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9380 0.2645 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9561 0.2651 sec/batch
# Nearest to i: pickering, excused, assyrian, reaped, know, think, zwinger, mihai,
# Nearest to than: eastwards, less, prices, equal, but, inheriting, gout, exceeding,
# Nearest to between: deeps, neogene, pneumatic, jebel, chakras, earthbound, revert, accuracy,
# Nearest to american: animist, barrett, asian, tach, medals, trey, calista, kennedy,
# Nearest to the: of, a, in, is, by, each, from, been,
# Nearest to b: washburn, mahmud, broglie, decimals, exponentiation, respectively, neumann, hippocrates,
# Nearest to or: cypriot, kihei, carbons, stakeholders, means, penalties, accompanying, oxidise,
# Nearest to who: aaronic, their, implanted, bornemisza, lived, entangling, disloyalty, revival,
# Nearest to gold: sardines, manganese, ore, duklja, potash, partially, glue, rowing,
# Nearest to operations: sensitive, panzer, wagons, combination, vectors, tekniska, macao, anselm,
# Nearest to except: conjunctivitis, oft, progeny, troughs, inlay, contest, petrie, polyhedron,
# Nearest to existence: contemplation, pontiff, waff, judgement, singularity, beings, propriety, authorizes,
# Nearest to rise: kv, greater, stuck, decreasing, precipitation, hirschfeld, stagnated, awoke,
# Nearest to placed: tibia, silicone, mariani, flamethrower, krapina, propel, refractory, mace,
# Nearest to san: francisco, cuyo, kobe, california, ribeira, juan, diego, nakata,
# Nearest to hold: bureaucrats, replay, tonalsoft, crossrail, afghans, entangled, gamble, mohs,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0010 0.2694 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0018 0.2718 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9650 0.2720 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0182 0.2642 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0425 0.2649 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9234 0.2657 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9818 0.2640 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0079 0.2642 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0159 0.2655 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9920 0.2641 sec/batch
# Nearest to i: pickering, excused, assyrian, think, know, fer, zwinger, mihai,
# Nearest to than: eastwards, less, prices, but, inheriting, equal, gout, noddy,
# Nearest to between: pneumatic, neogene, deeps, chakras, liberalization, jebel, revert, accuracy,
# Nearest to american: barrett, animist, actor, tach, athlete, medals, haas, trey,
# Nearest to the: of, by, a, in, is, from, each, also,
# Nearest to b: washburn, broglie, mahmud, virologist, russian, liston, neumann, magnus,
# Nearest to or: means, heb, stakeholders, maududi, sharpest, kihei, cypriot, penalties,
# Nearest to who: aaronic, their, implanted, bornemisza, mitford, entangling, lived, disloyalty,
# Nearest to gold: sardines, duklja, manganese, ore, rowing, metals, potash, passionate,
# Nearest to operations: sensitive, panzer, wagons, combination, tekniska, macao, combined, anselm,
# Nearest to except: conjunctivitis, oft, progeny, contest, inlay, fielding, polyhedron, troughs,
# Nearest to existence: contemplation, pontiff, waff, singularity, notions, authorizes, bergman, coldly,
# Nearest to rise: kv, greater, hirschfeld, awoke, duels, barristers, stuck, decreasing,
# Nearest to placed: tibia, flamethrower, mariani, mace, silicone, unsanitary, krapina, manoeuvres,
# Nearest to san: francisco, cuyo, kobe, california, nakata, ribeira, chased, diego,
# Nearest to hold: bureaucrats, tonalsoft, replay, afghans, gamble, entangled, crossrail, mohs,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0022 0.2665 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9939 0.2645 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0034 0.2641 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9768 0.2663 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0326 0.2658 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9767 0.2645 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9757 0.2640 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9706 0.2643 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9686 0.2636 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0311 0.2685 sec/batch
# Nearest to i: pickering, excused, think, zwinger, assyrian, am, know, you,
# Nearest to than: less, eastwards, prices, but, inheriting, equal, simpler, pluralism,
# Nearest to between: neogene, deeps, pneumatic, chakras, revert, jebel, liberalization, accuracy,
# Nearest to american: animist, barrett, tach, actor, haas, medals, asian, trey,
# Nearest to the: of, by, a, in, from, is, was, been,
# Nearest to b: washburn, mahmud, broglie, virologist, decimals, hippocrates, liston, respectively,
# Nearest to or: penalties, means, stakeholders, cypriot, improper, kihei, sharpest, cases,
# Nearest to who: their, aaronic, entangling, implanted, lived, disloyalty, mitford, bornemisza,
# Nearest to gold: sardines, manganese, metals, ore, duklja, precious, potash, reserves,
# Nearest to operations: sensitive, panzer, wagons, macao, combination, tekniska, combined, anselm,
# Nearest to except: conjunctivitis, oft, progeny, modicum, additional, inlay, contest, fielding,
# Nearest to existence: contemplation, waff, pontiff, singularity, authorizes, coldly, notions, judgement,
# Nearest to rise: kv, greater, awoke, hirschfeld, economic, decreasing, stagnated, barristers,
# Nearest to placed: tibia, mariani, flamethrower, mace, manoeuvres, haw, yeoman, scalars,
# Nearest to san: francisco, cuyo, nakata, kobe, california, ribeira, diego, juan,
# ...
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9060 0.2700 sec/batch
# Nearest to i: think, am, myself, you, excused, ti, know, zwinger,
# Nearest to than: less, but, even, more, have, eratosthenes, zero, much,
# Nearest to between: and, from, revert, in, to, of, the, chakras,
# Nearest to american: animist, ebb, calista, cooke, actor, tach, barrett, haas,
# Nearest to the: of, in, by, a, and, for, is, first,
# Nearest to b: mahmud, washburn, dudley, correspondingly, entrepreneur, american, ballerina, dirkszoon,
# Nearest to or: the, of, other, a, is, be, may, are,
# Nearest to who: their, albarn, aaronic, implanted, requisite, mitford, euhemerus, marrow,
# Nearest to gold: medal, jewelry, manganese, metals, precious, phosphate, sardines, ore,
# Nearest to operations: sensitive, panzer, oversee, intelligence, combination, macao, assisted, incrementing,
# Nearest to except: parenthesis, nehemiah, conjunctivitis, oft, grill, polyhedron, bait, contest,
# Nearest to existence: contemplation, reinvented, pontiff, atheistic, authorizes, lukewarm, ayer, cambrian,
# Nearest to rise: hirschfeld, trans, egos, role, polarized, litigation, barristers, intensified,
# Nearest to placed: arabesque, sibilant, yeoman, tibia, dinky, flamethrower, mace, silicone,
# Nearest to san: francisco, california, jose, diego, cuyo, nakata, sacramento, bernardino,
# Nearest to hold: mohs, gamble, bureaucrats, laoghaire, selberg, archaeopteryx, tanganyika, rampant,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8280 0.2688 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8606 0.2643 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8304 0.2645 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8448 0.2657 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8786 0.2627 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8600 0.2649 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8883 0.2645 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8478 0.2644 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8715 0.2644 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8471 0.2652 sec/batch
# Nearest to i: think, am, myself, you, excused, ti, zwinger, assyrian,
# Nearest to than: less, but, eratosthenes, more, even, much, roughly, one,
# Nearest to between: and, in, to, of, revert, from, the, on,
# Nearest to american: animist, ebb, calista, tach, barrett, native, cooke, americans,
# Nearest to the: of, in, by, a, and, from, was, first,
# Nearest to b: mahmud, washburn, dudley, correspondingly, futures, dirkszoon, ballerina, decimals,
# Nearest to or: the, be, is, of, other, a, also, behistun,
# Nearest to who: their, albarn, aaronic, requisite, mitford, euhemerus, implanted, lived,
# Nearest to gold: metals, manganese, jewelry, precious, medal, phosphate, sardines, ore,
# Nearest to operations: sensitive, panzer, intelligence, oversee, assisted, combination, anselm, macao,
# Nearest to except: parenthesis, nehemiah, grill, oft, jvm, abs, textbooks, bait,
# Nearest to existence: reinvented, contemplation, atheistic, pontiff, ayer, authorizes, lukewarm, cambrian,
# Nearest to rise: hirschfeld, trans, role, egos, intensified, polarized, northcote, barristers,
# Nearest to placed: sibilant, arabesque, yeoman, dinky, tibia, mace, mariani, makes,
# Nearest to san: francisco, california, diego, jose, cuyo, nakata, juvenal, sacramento,
# Nearest to hold: mohs, bureaucrats, gamble, rampant, selberg, laoghaire, archaeopteryx, tanganyika,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8546 0.2672 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8504 0.2655 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8536 0.2667 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8367 0.2630 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8911 0.2656 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8571 0.2664 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9737 0.2652 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8799 0.2648 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9174 0.2634 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8147 0.2645 sec/batch
# Nearest to i: think, am, myself, you, ti, know, zwinger, excused,
# Nearest to than: less, but, more, eratosthenes, much, smaller, roughly, even,
# Nearest to between: and, in, of, the, from, revert, to, recognized,
# Nearest to american: animist, ebb, barrett, tach, native, caucasian, americans, calista,
# Nearest to the: of, in, by, a, and, from, as, for,
# Nearest to b: mahmud, washburn, futures, ballerina, dudley, correspondingly, strafford, including,
# Nearest to or: of, is, be, other, the, such, behistun, a,
# Nearest to who: their, albarn, lived, people, requisite, destitute, aaronic, declan,
# Nearest to gold: precious, jewelry, metals, medal, manganese, sardines, ore, phosphate,
# Nearest to operations: sensitive, intelligence, panzer, oversee, adm, assigned, assisted, macao,
# Nearest to except: parenthesis, grill, nehemiah, oft, jvm, centimeter, conjunctivitis, modicum,
# Nearest to existence: reinvented, contemplation, atheistic, pontiff, lukewarm, authorizes, uballit, ayer,
# Nearest to rise: hirschfeld, trans, intensified, role, polarized, northcote, barristers, litigation,
# Nearest to placed: sibilant, arabesque, yeoman, dinky, mariani, mace, misconceptions, revoking,
# Nearest to san: francisco, california, diego, jose, nakata, cuyo, juvenal, sacramento,
# Nearest to hold: mohs, gamble, rampant, tanganyika, bureaucrats, selberg, laoghaire, mcconnell,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7788 0.2649 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8712 0.2646 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8149 0.2658 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8751 0.2656 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8362 0.2639 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8788 0.2650 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8946 0.1514 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7990 0.2653 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8286 0.2649 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8283 0.2655 sec/batch
# Nearest to i: think, myself, am, you, zwinger, ti, assyrian, excused,
# Nearest to than: less, but, more, have, much, zero, eratosthenes, roughly,
# Nearest to between: from, and, in, revert, of, the, on, recognized,
# Nearest to american: animist, actor, b, athlete, barrett, songwriter, musician, cartoonist,
# Nearest to the: of, in, by, a, and, from, to, first,
# Nearest to b: mahmud, washburn, american, composer, pediatrician, virologist, entrepreneur, strafford,
# Nearest to or: of, the, other, is, may, be, and, such,
# Nearest to who: their, his, requisite, albarn, lived, mitford, implanted, declan,
# Nearest to gold: precious, jewelry, medal, metals, manganese, phosphate, sardines, duklja,
# Nearest to operations: sensitive, oversee, panzer, combination, intelligence, tattoo, adm, macao,
# Nearest to except: parenthesis, grill, jvm, centimeter, conjunctivitis, oft, abs, bait,
# Nearest to existence: contemplation, reinvented, atheistic, ayer, pontiff, lukewarm, ontological, uballit,
# Nearest to rise: trans, hirschfeld, role, polarized, barristers, northcote, decades, intensified,
# Nearest to placed: sibilant, arabesque, yeoman, dinky, tibia, makes, mace, haw,
# Nearest to san: francisco, california, diego, jose, cuyo, nakata, sacramento, juvenal,
# Nearest to hold: mohs, gamble, selberg, rampant, tanganyika, bureaucrats, archaeopteryx, ferrat,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8290 0.2673 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8104 0.2648 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8496 0.2665 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7981 0.2714 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8509 0.2669 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8200 0.2672 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.9045 0.2649 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7711 0.2655 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7923 0.2680 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8150 0.2764 sec/batch
# Nearest to i: think, am, myself, you, zwinger, ti, know, assyrian,
# Nearest to than: less, but, more, zero, much, have, one, even,
# Nearest to between: and, in, of, the, from, to, on, revert,
# Nearest to american: animist, ebb, caucasian, native, barrett, calista, enables, athlete,
# Nearest to the: of, a, in, by, is, and, for, from,
# Nearest to b: washburn, mahmud, futures, including, decimals, correspondingly, dyadic, respectively,
# Nearest to or: the, of, other, by, is, a, may, such,
# Nearest to who: their, requisite, aaronic, albarn, his, lived, implanted, declan,
# Nearest to gold: precious, jewelry, medal, manganese, metals, phosphate, sardines, ore,
# Nearest to operations: sensitive, panzer, intelligence, oversee, combination, adm, tattoo, circa,
# Nearest to except: nehemiah, parenthesis, oft, grill, conjunctivitis, bait, centimeter, paws,
# Nearest to existence: reinvented, contemplation, pontiff, atheistic, authorizes, lukewarm, ayer, does,
# Nearest to rise: hirschfeld, trans, litigation, barristers, role, polarized, kv, northcote,
# Nearest to placed: sibilant, makes, yeoman, dinky, arabesque, end, side, mace,
# Nearest to san: francisco, california, jose, diego, nakata, cuyo, sacramento, bernardino,
# Nearest to hold: mohs, gamble, rampant, selberg, bureaucrats, tanganyika, archaeopteryx, status,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7635 0.2757 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8254 0.2727 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8597 0.2744 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8424 0.2751 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8128 0.2738 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9142 0.2783 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8220 0.2676 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8304 0.2673 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8331 0.2657 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8587 0.2664 sec/batch
# Nearest to i: think, am, myself, you, ti, zwinger, excused, bouvines,
# Nearest to than: less, but, more, much, have, zero, smaller, roughly,
# Nearest to between: in, and, of, from, the, to, on, revert,
# Nearest to american: animist, ebb, athlete, native, calista, cartoonist, barrett, cooke,
# Nearest to the: of, in, by, a, and, is, for, also,
# Nearest to b: washburn, mahmud, american, pediatrician, including, virologist, futures, dyadic,
# Nearest to or: of, the, be, is, may, such, other, by,
# Nearest to who: their, aaronic, albarn, requisite, people, implanted, to, his,
# Nearest to gold: precious, jewelry, medal, manganese, metals, phosphate, sardines, ore,
# Nearest to operations: intelligence, panzer, sensitive, assisted, oversee, adm, tattoo, combination,
# Nearest to except: parenthesis, nehemiah, oft, jvm, grill, centimeter, entitled, abs,
# Nearest to existence: reinvented, contemplation, atheistic, lukewarm, pontiff, ayer, authorizes, ontological,
# Nearest to rise: hirschfeld, trans, litigation, role, egos, barristers, polarized, northcote,
# Nearest to placed: sibilant, makes, arabesque, dinky, yeoman, side, sported, misconceptions,
# Nearest to san: francisco, california, diego, jose, cuyo, nakata, sacramento, bernardino,
# Nearest to hold: mohs, gamble, tanganyika, rampant, bureaucrats, contains, selberg, laoghaire,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8522 0.2680 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8404 0.2654 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8265 0.2665 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8442 0.2663 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8600 0.2652 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8476 0.2667 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8244 0.2661 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8264 0.2686 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8145 0.2660 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8115 0.2634 sec/batch
# Nearest to i: think, you, am, myself, ti, zwinger, ve, excused,
# Nearest to than: less, more, but, much, have, are, smaller, even,
# Nearest to between: and, in, from, of, to, the, revert, on,
# Nearest to american: animist, ebb, native, caucasian, americans, induces, living, calista,
# Nearest to the: of, in, by, a, and, from, for, an,
# Nearest to b: washburn, mahmud, including, futures, strafford, correspondingly, hippocrates, dyadic,
# Nearest to or: be, of, the, is, may, such, to, a,
# Nearest to who: their, albarn, requisite, to, people, lived, euhemerus, his,
# Nearest to gold: precious, jewelry, metals, medal, manganese, ore, sardines, phosphate,
# Nearest to operations: intelligence, panzer, oversee, sensitive, adm, ordinary, assigned, assisted,
# Nearest to except: parenthesis, nehemiah, entitled, oft, grill, jvm, centimeter, bait,
# Nearest to existence: reinvented, contemplation, atheistic, lukewarm, pontiff, cambrian, authorizes, uballit,
# Nearest to rise: hirschfeld, trans, litigation, polarized, barristers, northcote, role, decades,
# Nearest to placed: sibilant, arabesque, makes, yeoman, dinky, drove, mace, side,
# Nearest to san: francisco, california, diego, jose, cuyo, nakata, sacramento, medici,
# Nearest to hold: gamble, mohs, ferrat, rampant, tanganyika, selberg, status, bureaucrats,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8426 0.2682 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8275 0.2667 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9315 0.2679 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9202 0.2648 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8822 0.2647 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8750 0.2692 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7560 0.2774 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8386 0.2822 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7508 0.2648 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8788 0.2648 sec/batch
# Nearest to i: think, you, myself, am, ti, zwinger, know, my,
# Nearest to than: less, but, more, much, zero, roughly, smaller, have,
# Nearest to between: and, of, to, from, in, the, revert, recognized,
# Nearest to american: actor, animist, b, musician, athlete, songwriter, cartoonist, barrett,
# Nearest to the: of, in, a, by, from, for, also, and,
# Nearest to b: american, washburn, mahmud, one, politician, pediatrician, strafford, composer,
# Nearest to or: the, of, and, a, is, also, be, are,
# Nearest to who: their, albarn, people, implanted, requisite, several, mitford, lived,
# Nearest to gold: precious, jewelry, medal, metals, phosphate, ore, sardines, duklja,
# Nearest to operations: intelligence, oversee, panzer, sensitive, assigned, adm, macao, tattoo,
# Nearest to except: parenthesis, centimeter, oft, grill, nehemiah, jvm, abs, paws,
# Nearest to existence: lukewarm, atheistic, reinvented, contemplation, pontiff, theologico, uballit, ayer,
# Nearest to rise: trans, hirschfeld, decades, polarized, northcote, litigation, barristers, role,
# Nearest to placed: sibilant, yeoman, arabesque, makes, side, sported, mace, dinky,
# Nearest to san: francisco, california, diego, jose, cuyo, sacramento, nakata, bernardino,
# Nearest to hold: mohs, gamble, ferrat, contains, tanganyika, selberg, bureaucrats, rampant,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8626 0.2669 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8387 0.2645 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
