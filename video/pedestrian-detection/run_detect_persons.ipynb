# %%
#%run detect.py --images images/
#%run detect.py --images '/media/sf_OC_RESINET/process/ResiIndoor05-Pond5/indoor_door_004/'

#%run detect_to_file.py --images '/media/sf_OC_RESINET/process/ResiIndoor05-Pond5/indoor_060/'
#%run detect_to_file.py --images '/media/sf_OC_RESINET/process/ResiIndoor05-Pond5/indoor_door_003/'
# %run detect_to_file.py --images '/media/sf_OC_RESINET/process/ResiIndoor05-Pond5/front_door_014/'
# Out:
# [INFO] output_00279.jpg: 0 original boxes, 0 after suppression
# [INFO] output_00050.jpg: 0 original boxes, 0 after suppression
# [INFO] output_00283.jpg: 0 original boxes, 0 after suppression
# [INFO] output_00122.jpg: 0 original boxes, 0 after suppression
# [INFO] output_00154.jpg: 1 original boxes, 1 after suppression
# [INFO] output_00338.jpg: 0 original boxes, 0 after suppression
# [INFO] output_00236.jpg: 0 original boxes, 0 after suppression
# [INFO] output_00027.jpg: 0 original boxes, 0 after suppression
# [INFO] output_00260.jpg: 1 original boxes, 1 after suppression
# [INFO] output_00025.jpg: 0 original boxes, 0 after suppression
# [INFO] output_00226.jpg: 0 original boxes, 0 after suppression
# [INFO] output_00357.jpg: 1 original boxes, 1 after suppression
# [INFO] output_00359.jpg: 1 original boxes, 1 after suppression
# [INFO] output_00372.jpg: 1 original boxes, 1 after suppression
# [INFO] output_00382.jpg: 1 original boxes, 1 after suppression
# ...
